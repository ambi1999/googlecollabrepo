# %% [markdown]
# <a href="https://colab.research.google.com/github/ambi1999/googlecollabrepo/blob/main/Sol1_Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Applied Data Science for Innovation**
#
# ##**Loading Datasets From Various Sources**

# %% [markdown]
# #### **Importing Datasets using Inclusive Libraries**

# %% [markdown]
# **Import Dataset from google drive**
#
# ---

# %% [markdown]
# **Step 1:**
# Import the required libraries

# %%
# Placeholder for student's code (1 line of code)
# Task:Importing inclusive library 'csv'

# %%
import csv #importing inclusive library

# %% [markdown]
# **Step2:**
# Mount Google Drive

# %%
#Placeholder for student's code (2 lines of code)
#Task: Import google drive library to mount drive and write code to mount drive

# %%
from google.colab import drive #importing drive library
drive.mount('/content/drive') #mounting code
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Step 3:**
# Open Dataset from Drive

# %%
#Placeholder for student's code (Multiple lines of code)
#Task: Open csv file and print a single column of loaded DS

# %%
# Change the path of the CSV to your actual path in Google Drive

with open('/content/drive/MyDrive/Applied Data Science for Innovation/Module-1/downloaded_DS/covid_worldwide.csv') as df: # Opening the csv file as dataframe
    file = csv.reader(df) # Saving the data inside the variable
    for row in file: # For loop until the row ends.
        print (row[1]) # Printing only the first column of the dataset
# Out:
# Country
# USA
# India
# France
# Germany
# Brazil
# Japan
# S. Korea
# Italy
# UK
# Russia
# Turkey
# Spain
# Vietnam
# Australia
# Argentina
# Taiwan
# Netherlands
# Iran
# Mexico
# Indonesia
# Poland
# Colombia
# Austria
# Greece
# Portugal
# Ukraine
# Chile
# Malaysia
# Israel
# DPRK
# Thailand
# Belgium
# Czechia
# Canada
# Peru
# Switzerland
# Philippines
# South Africa
# Romania
# Denmark
# Hong Kong
# Sweden
# Serbia
# Iraq
# Singapore
# Hungary
# New Zealand
# Bangladesh
# Slovakia
# Georgia
# Jordan
# Ireland
# Pakistan
# Norway
# Finland
# Kazakhstan
# Slovenia
# Lithuania
# Bulgaria
# Morocco
# Croatia
# Lebanon
# Guatemala
# Bolivia
# Costa Rica
# Tunisia
# Cuba
# Ecuador
# UAE
# Uruguay
# Panama
# Mongolia
# Nepal
# Belarus
# Latvia
# Saudi Arabia
# Azerbaijan
# Paraguay
# Bahrain
# Sri Lanka
# Kuwait
# Dominican Republic
# Cyprus
# Myanmar
# Palestine
# Estonia
# Moldova
# Venezuela
# Egypt
# Libya
# China
# Ethiopia
# Qatar
# Réunion
# Honduras
# Armenia
# ...

# %% [markdown]
# **Download Dataset from Web link**
#
#
#
# ---

# %% [markdown]
# **Step1:**
# Import required libraries

# %%
#Placeholder for student's code (1 line of code)
#Task: Import 'urlretrieve' library

# %%
from urllib.request import urlretrieve #importing libraries

# %% [markdown]
# **Step 2:**
# Call the function to download from url and save in Drive

# %%
#Placeholder for student's code (2 lines of code)
#Task: Saving url in variable named url, download the dataset and save it in folder of your own choice to make an offline copy

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00611/accelerometer.csv' #saving url in variable named url


urlretrieve(url,'/content/drive/MyDrive/Applied Data Science for Innovation/Module-1/downloaded_DS/accelerometer.csv') # Retrieving the Storing the data inside the folder.
# Out:
# ('/content/drive/MyDrive/Applied Data Science for Innovation/Module-1/downloaded_DS/accelerometer.csv',
#  <http.client.HTTPMessage at 0x7e203dba1e10>)

# %% [markdown]
# **Step 3:**
# Open the dataset from Drive

# %%
#Placeholder for student's code (Multiple lines of code)
#Task: Open csv file and print a single column of loaded DS

# %%
with open('/content/drive/MyDrive/Applied Data Science for Innovation/Module-1/downloaded_DS/accelerometer.csv') as df: #openinig dataset as dataframe
    file = csv.reader(df, delimiter = ';') # This time setting up the delimiter as well
    for column in file:
        print (column[0])
# Out:
# Streaming output truncated to the last 5000 lines.
# 3,95,1.129,-0.117,-0.027
# 3,95,1.023,0.035,-0.277
# 3,95,0.992,0.102,-0.156
# 3,95,1.062,-0.160,-0.133
# 3,95,0.859,0.160,-0.242
# 3,95,1.027,-0.070,0.152
# 3,95,0.859,-0.020,-0.387
# 3,95,1.051,0.168,0.047
# 3,95,0.730,-0.258,-0.004
# 3,95,1.121,0.156,-0.273
# 3,95,0.934,0.004,-0.035
# 3,95,1.227,-0.094,-0.266
# 3,95,0.992,0.176,-0.168
# 3,95,1.246,-0.238,-0.160
# 3,95,0.816,0.129,-0.328
# 3,95,1.055,0.047,0.145
# 3,95,0.957,-0.129,-0.082
# 3,95,1.004,0.176,-0.172
# 3,95,0.922,0.047,0.184
# 3,95,0.758,0.004,-0.422
# 3,95,0.996,0.195,-0.004
# 3,95,0.719,-0.172,0.117
# 3,95,1.035,0.125,-0.336
# 3,95,0.824,-0.023,0.184
# 3,95,0.930,-0.055,-0.285
# 3,95,0.977,0.211,-0.102
# 3,95,1.281,-0.215,-0.191
# 3,95,1.016,0.105,-0.238
# 3,95,1.102,0.063,-0.035
# 3,95,0.855,-0.137,-0.059
# 3,95,0.902,0.164,-0.266
# 3,95,0.840,-0.004,0.234
# 3,95,1.027,-0.047,-0.426
# 3,95,1.008,0.227,-0.051
# 3,95,1.020,-0.270,-0.195
# 3,95,0.953,0.234,-0.215
# ...

# %% [markdown]
# ####**Import Datasets using Non Inclusive Libraries**

# %% [markdown]
# **Using Numpy**
#
# ---

# %%
#Placeholder for student's code (Multiple lines of code)
#Task: Import numpy library, store dataset in df and print the data

# %%
from numpy import genfromtxt # importing the library
df = genfromtxt('/content/drive/MyDrive/Applied Data Science for Innovation/Module-1/downloaded_DS/covid_worldwide.csv', delimiter=';',dtype=None) # Storing the data in the df
print (df) # Printing the data in the jupyter notebook
# Out:
# [b'Serial Number,Country,Total Cases,Total Deaths,Total Recovered,Active Cases,Total Test,Population'
#  b'1,USA,"104,196,861","1,132,935","101,322,779","1,741,147","1,159,832,679","334,805,269"'
#  b'2,India,"44,682,784","530,740","44,150,289","1,755","915,265,788","1,406,631,776"'
#  b'3,France,"39,524,311","164,233","39,264,546","95,532","271,490,188","65,584,518"'
#  b'4,Germany,"37,779,833","165,711","37,398,100","216,022","122,332,384","83,883,596"'
#  b'5,Brazil,"36,824,580","697,074","35,919,372","208,134","63,776,166","215,353,593"'
#  b'6,Japan,"32,588,442","68,399","21,567,425","10,952,618","92,144,639","125,584,838"'
#  b'7,S. Korea,"30,197,066","33,486","29,740,877","422,703","15,804,065","51,329,899"'
#  b'8,Italy,"25,453,789","186,833","25,014,986","251,970","265,478,247","60,262,770"'
#  b'9,UK,"24,274,361","204,171","24,020,088","50,102","522,526,476","68,497,907"'
#  b'10,Russia,"21,958,696","395,108","21,356,008","207,580","273,400,000","145,805,947"'
# ...

# %% [markdown]
# **Using Pandas**

# %%
#Placeholder for student's code (Multiple lines of code)
#Task: Import pandas library, read dataframe and print

# %%
import pandas as pd # Importing the pandas library
df = pd.read_csv('/content/drive/MyDrive/Applied Data Science for Innovation/Module-1/downloaded_DS/covid_worldwide.csv') # Reading the file and storing the data inside the variable df
print(df) # Printing the Data in the jupyter notebook
# Out:
#      Serial Number           Country  Total Cases Total Deaths  \
# 0                1               USA  104,196,861    1,132,935
# 1                2             India   44,682,784      530,740
# 2                3            France   39,524,311      164,233
# 3                4           Germany   37,779,833      165,711
# 4                5            Brazil   36,824,580      697,074
# ..             ...               ...          ...          ...
# 226            227  Diamond Princess          712           13
# 227            228      Vatican City           29          NaN
# 228            229    Western Sahara           10            1
# 229            230        MS Zaandam            9            2
# 230            231           Tokelau            5          NaN
#
#     Total Recovered Active Cases     Total Test     Population
# 0       101,322,779    1,741,147  1,159,832,679    334,805,269
# 1        44,150,289        1,755    915,265,788  1,406,631,776
# ...

# %%
#Placeholder for student's code (1 line of code)
#Task: Display 1st five rows of dataframe using pandas head function

# %%
# Display the top 5 rows
df.head(5)
# Out:
#    Serial Number  Country  Total Cases Total Deaths Total Recovered  \
# 0              1      USA  104,196,861    1,132,935     101,322,779
# 1              2    India   44,682,784      530,740      44,150,289
# 2              3   France   39,524,311      164,233      39,264,546
# 3              4  Germany   37,779,833      165,711      37,398,100
# 4              5   Brazil   36,824,580      697,074      35,919,372
#
#   Active Cases     Total Test     Population
# 0    1,741,147  1,159,832,679    334,805,269
# 1        1,755    915,265,788  1,406,631,776
# 2       95,532    271,490,188     65,584,518
# 3      216,022    122,332,384     83,883,596
# 4      208,134     63,776,166    215,353,593

# %%
#Placeholder for student's code (1 line of code)
#Task: Display last five rows of dataframe using pandas tail function

# %%
# Display the bottom 5 rows
df.tail(5)
# Out:
#      Serial Number           Country Total Cases Total Deaths Total Recovered  \
# 226            227  Diamond Princess         712           13             699
# 227            228      Vatican City          29          NaN              29
# 228            229    Western Sahara          10            1               9
# 229            230        MS Zaandam           9            2               7
# 230            231           Tokelau           5          NaN             NaN
#
#     Active Cases Total Test Population
# 226            0        NaN        NaN
# 227            0        NaN        799
# 228            0        NaN    626,161
# 229            0        NaN        NaN
# 230            5        NaN      1,378

# %%
#Placeholder for student's code (1 line of code)
#Task: Checking the data type of each field/colummn

# %%
# Checking the data type of each field/colummn
df.dtypes
# Out:
# Serial Number       int64
# Country            object
# Total Cases        object
# Total Deaths       object
# Total Recovered    object
# Active Cases       object
# Total Test         object
# Population         object
# dtype: object

# %%
#Placeholder for student's code (1 line of code)
#Task: Dropping irrelevant columns

# %%
# Dropping irrelevant columns
df = df.drop(['Population'], axis=1)
df.dtypes
# Out:
# Serial Number       int64
# Country            object
# Total Cases        object
# Total Deaths       object
# Total Recovered    object
# Active Cases       object
# Total Test         object
# dtype: object

# %%
#Placeholder for student's code (1 line of code)
#Task: Describe dataset statistics

# %%
df.describe()
# Out:
#        Serial Number
# count     231.000000
# mean      116.000000
# std        66.828138
# min         1.000000
# 25%        58.500000
# 50%       116.000000
# 75%       173.500000
# max       231.000000

# %%
df['Total Deaths'].describe()
# Out:
# count     225
# unique    213
# top        38
# freq        3
# Name: Total Deaths, dtype: object

# %%
#Placeholder for student's code (1 line of code)
#Task: Rename column names

# %%
# Renaming Colummns
df = df.rename(columns={"Total Test": "Total Tests"})
df.head(5)
# Out:
#    Serial Number  Country  Total Cases Total Deaths Total Recovered  \
# 0              1      USA  104,196,861    1,132,935     101,322,779
# 1              2    India   44,682,784      530,740      44,150,289
# 2              3   France   39,524,311      164,233      39,264,546
# 3              4  Germany   37,779,833      165,711      37,398,100
# 4              5   Brazil   36,824,580      697,074      35,919,372
#
#   Active Cases    Total Tests
# 0    1,741,147  1,159,832,679
# 1        1,755    915,265,788
# 2       95,532    271,490,188
# 3      216,022    122,332,384
# 4      208,134     63,776,166

# %%
#Placeholder for student's code (1 line of code)
#Task: Finding total number of rows and columns. Hint: Use shape function from pandas

# %%
# Finding total number of rows and columns
df.shape
# Out:
# (231, 7)

# %%
#Placeholder for student's code (1 line of code)
#Task: Find the number of row containing duplicate data

# %%
# Finding the number of row containing duplicate data
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 7)

# %%
#Placeholder for student's code (1 line of code)
#Task: Count the number of rows before removing the data

# %%
# Used to count the number of rows before removing the data
df.count()
# Out:
# Serial Number      231
# Country            231
# Total Cases        231
# Total Deaths       225
# Total Recovered    210
# Active Cases       212
# Total Tests        213
# dtype: int64

# %%
#Placeholder for student's code (1 line of code)
#Task: Find the null values. Used to find the number of rows having missing values

# %%
# Finding the null values. Used to find the number of rows having missing values
print(df.isnull().sum())
# Out:
# Serial Number       0
# Country             0
# Total Cases         0
# Total Deaths        6
# Total Recovered    21
# Active Cases       19
# Total Tests        18
# dtype: int64

# %%
#Placeholder for student's code (1 line of code)
#Task:Drop the missing values

# %%
# Dropping the missing values.Should be done carefully else it will end up
# dropping important rows having data
df = df.dropna()
df.count()
#print(df.isnull().sum())
# Out:
# Serial Number      196
# Country            196
# Total Cases        196
# Total Deaths       196
# Total Recovered    196
# Active Cases       196
# Total Tests        196
# dtype: int64

# %% [markdown]
# ### References
#
# ### Some useful websites
#
# <br> 1. https://pandas.pydata.org/
# <br> 2. http://www.numpy.org/
# <br> 3. https://pypi.org/project/psycopg2/
